# %%
df = pd.read_csv('data.csv')

# %%
import pandas as pd

# %%
df
# Out:
#                                                   title   type  \
# 0                                                 Ariel  movie
# 1                                   Shadows in Paradise  movie
# 2                                          Forrest Gump  movie
# 3                                     The Fifth Element  movie
# 4                                    My Life Without Me  movie
# ...                                                 ...    ...
# 9840  Shin Tennis no Ouji-sama: Hyoutei vs Rikkai - ...     tv
# 9841                                     Gangnam B-Side     tv
# 9842                                          Concordia     tv
# 9843                   The Disappearance of Kimmy Diore     tv
# 9844                              Subscription Adultery     tv
#
#                          genres  releaseYear      imdbId  imdbAverageRating  \
# 0        Comedy, Crime, Romance       1988.0   tt0094675                7.4
# ...

# %%
df.head()
# Out:
#                  title   type                     genres  releaseYear  \
# 0                Ariel  movie     Comedy, Crime, Romance       1988.0
# 1  Shadows in Paradise  movie       Comedy, Drama, Music       1986.0
# 2         Forrest Gump  movie             Drama, Romance       1994.0
# 3    The Fifth Element  movie  Action, Adventure, Sci-Fi       1997.0
# 4   My Life Without Me  movie             Drama, Romance       2003.0
#
#       imdbId  imdbAverageRating  imdbNumVotes availableCountries
# 0  tt0094675                7.4        8776.0                 JP
# 1  tt0092149                7.5        7538.0                 JP
# 2  tt0109830                8.8     2320505.0                 JP
# 3  tt0119116                7.6      517631.0                 JP
# 4  tt0314412                7.4       26044.0                 JP

# %%
df.describe()
# Out:
#        releaseYear  imdbAverageRating  imdbNumVotes
# count  9821.000000        8671.000000  8.671000e+03
# mean   2011.465635           6.561158  3.684700e+04
# std      13.892457           1.053589  1.471665e+05
# min    1929.000000           2.000000  5.000000e+00
# 25%    2008.000000           6.000000  1.480000e+02
# 50%    2016.000000           6.700000  9.830000e+02
# 75%    2021.000000           7.300000  7.775000e+03
# max    2025.000000           9.500000  2.965080e+06

# %%
# print(df.duplicate)
df = df.drop_duplicates()
df
# Out:
#                                                   title   type  \
# 0                                                 Ariel  movie
# 1                                   Shadows in Paradise  movie
# 2                                          Forrest Gump  movie
# 3                                     The Fifth Element  movie
# 4                                    My Life Without Me  movie
# ...                                                 ...    ...
# 9840  Shin Tennis no Ouji-sama: Hyoutei vs Rikkai - ...     tv
# 9841                                     Gangnam B-Side     tv
# 9842                                          Concordia     tv
# 9843                   The Disappearance of Kimmy Diore     tv
# 9844                              Subscription Adultery     tv
#
#                          genres  releaseYear      imdbId  imdbAverageRating  \
# 0        Comedy, Crime, Romance       1988.0   tt0094675                7.4
# ...

# %%
print(df.isnull().sum())
# Out:
# title                 293
# type                    0
# genres                169
# releaseYear             8
# imdbId                623
# imdbAverageRating     891
# imdbNumVotes          891
# availableCountries      0
# dtype: int64

# %%
df.fillna(value={'column_name': 'default_value'}, inplace=True)  # Replace 'default_value' as needed

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9562 entries, 0 to 9844
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               9269 non-null   object
#  1   type                9562 non-null   object
#  2   genres              9393 non-null   object
#  3   releaseYear         9554 non-null   float64
#  4   imdbId              8939 non-null   object
#  5   imdbAverageRating   8671 non-null   float64
#  6   imdbNumVotes        8671 non-null   float64
#  7   availableCountries  9562 non-null   object
# dtypes: float64(3), object(5)
# memory usage: 672.3+ KB

# %%
df = df.dropna()
df
# Out:
#                                                   title   type  \
# 0                                                 Ariel  movie
# 1                                   Shadows in Paradise  movie
# 2                                          Forrest Gump  movie
# 3                                     The Fifth Element  movie
# 4                                    My Life Without Me  movie
# ...                                                 ...    ...
# 9838                                       Black Clover     tv
# 9839                          Cells at Work! Code Black     tv
# 9840  Shin Tennis no Ouji-sama: Hyoutei vs Rikkai - ...     tv
# 9842                                          Concordia     tv
# 9843                   The Disappearance of Kimmy Diore     tv
#
#                             genres  releaseYear      imdbId  \
# 0           Comedy, Crime, Romance       1988.0   tt0094675
# 1             Comedy, Drama, Music       1986.0   tt0092149
# ...

# %%
print(df.isna().sum())
# Out:
# title                 0
# type                  0
# genres                0
# releaseYear           0
# imdbId                0
# imdbAverageRating     0
# imdbNumVotes          0
# availableCountries    0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df['releaseYear'] = df['releaseYear'].fillna(0).astype(int)
release_trends = df['releaseYear'].value_counts().sort_index()
print(release_trends)
# Out:
# releaseYear
# 1929      1
# 1932      1
# 1933      1
# 1936      1
# 1937      1
#        ...
# 2020    442
# 2021    547
# 2022    672
# 2023    573
# 2024    322
# Name: count, Length: 88, dtype: int64
# /tmp/ipykernel_11922/1779028637.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['releaseYear'] = df['releaseYear'].fillna(0).astype(int)

# %%
print(df['type'].unique())
# Out:
# ['movie' 'tv']

# %%
# Count the occurrences of each type
type_counts = df['type'].value_counts()

print(type_counts)
# Out:
# type
# movie    5461
# tv       3199
# Name: count, dtype: int64

# %%
print(df['genres'].unique())
# Out:
# ['Comedy, Crime, Romance' 'Comedy, Drama, Music' 'Drama, Romance'
#  'Action, Adventure, Sci-Fi' 'Action, Adventure, Fantasy' 'Drama, Western'
#  'Mystery, Sci-Fi, Thriller' 'Drama, Sport' 'Mystery, Thriller'
#  'Action, Drama, Sci-Fi' 'Action, Adventure, Drama' 'Action, Adventure'
#  'Comedy, Drama, Romance' 'Action, Adventure, Horror' 'Comedy, Crime'
#  'Comedy, Romance' 'Drama, Romance, Thriller' 'Adventure, Comedy, Family'
#  'Comedy, Crime, Drama' 'Drama, Mystery, Sci-Fi' 'Drama, Fantasy, Romance'
#  'Action, Animation, Drama' 'Comedy, Drama' 'Action, Crime, Drama'
#  'Crime, Thriller' 'Adventure, Comedy, Sci-Fi' 'Action, Horror, Sci-Fi'
#  'Horror, Mystery, Thriller' 'Action, Crime, Mystery'
#  'Action, Crime, Thriller' 'Crime, Drama' 'Action, Crime, Romance' 'Drama'
#  'Crime, Drama, Mystery' 'Drama, Mystery, Thriller' 'Horror, Sci-Fi'
#  'Action, Crime, Fantasy' 'Action, Sci-Fi' 'Biography, Drama, Mystery'
# ...

# %%
print(df[['title', 'genres']].head())
# Out:
#                  title                     genres
# 0                Ariel     Comedy, Crime, Romance
# 1  Shadows in Paradise       Comedy, Drama, Music
# 2         Forrest Gump             Drama, Romance
# 3    The Fifth Element  Action, Adventure, Sci-Fi
# 4   My Life Without Me             Drama, Romance
